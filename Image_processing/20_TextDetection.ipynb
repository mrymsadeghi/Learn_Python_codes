# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
import easyocr

# %%
car_img = cv.imread("Images/Car_plate2.jpg")
car_plate_img = cv.imread("Images/plate2_2.jpg", 0)
plt.imshow(cv.cvtColor(car_plate_img, cv.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['fa'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
plate_info = reader.readtext(car_plate_img)
print(plate_info)
# Out:
# [[[[25, 1], [282, 1], [282, 61], [25, 61]], '١١ 9 ١١٤٢٢', 0.5997751554882397]]

# %%
plate_text = plate_info[0][-2]
plate_text
# Out:
# '١١ 9 ١١٤٢٢'
